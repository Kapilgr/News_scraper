# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get('https://www.onlinekhabar.com/')

# %%
web.content # it gives all the content
# Out:
# b'<!doctype html>\n<html lang="en-US">\n\n<head>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <link rel="profile" href="https://gmpg.org/xfn/11">\n    <meta property="fb:pages" content="108349739223556" />\n    <meta property="fb:app_id" content="366639890155270" />\n    <title>Online Khabar \xe2\x80\x93 No 1 News Portal from Nepal in Nepali. &#8211; No 1 News Portal from Nepal in Nepali.</title>\n<meta name=\'robots\' content=\'max-image-preview:large\' />\n<link rel="alternate" type="application/rss+xml" title="Online Khabar &raquo; Feed" href="https://www.onlinekhabar.com/feed" />\n<link rel="alternate" type="application/rss+xml" title="Online Khabar &raquo; Comments Feed" href="https://www.onlinekhabar.com/comments/feed" />\n<link rel="alternate" title="oEmbed (JSON)" type="application/json+oembed" href="https://www.onlinekhabar.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.onlinekhabar.com%2F" />\n<link rel="alte
# ...

# %%
soup=BeautifulSoup(web.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="108349739223556" property="fb:pages">
# <meta content="366639890155270" property="fb:app_id">
# <title>Online Khabar – No 1 News Portal from Nepal in Nepali. – No 1 News Portal from Nepal in Nepali.</title>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://www.onlinekhabar.com/feed" rel="alternate" title="Online Khabar » Feed" type="application/rss+xml">
# <link href="https://www.onlinekhabar.com/comments/feed" rel="alternate" title="Online Khabar » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.onlinekhabar.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.onlinekhabar.com%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
# ...

# %%
cat=soup.find_all("div",class_="menu-primary-menu-container")
cat
# Out:
# [<div class="menu-primary-menu-container"><ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item current_page_item menu-item-735159" id="menu-item-735159"><a aria-current="page" href="/">होमपेज</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1413258" id="menu-item-1413258"><a href="https://www.onlinekhabar.com/content/news/rastiya">समाचार</a></li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-735066" id="menu-item-735066"><a href="https://www.onlinekhabar.com/business">बिजनेस</a></li>
#  <li class="lifestyle-megamenu-append-wrap menu-item menu-item-type-post_type menu-item-object-page menu-item-735161" id="menu-item-735161"><a href="https://www.onlinekhabar.com/lifestyle">जीवनशैली</a></li>
# ...

# %%
for i in cat:
    x=i.text

print(x)
# Out:
# होमपेज
# समाचार
# बिजनेस
# जीवनशैली
# मनोरञ्जन
# विचार
# खेलकुद
# अन्य

# %%
cat1=soup.find_all('ul',id="primary-menu")
cat1
# Out:
# [<ul class="menu" id="primary-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item current_page_item menu-item-735159" id="menu-item-735159"><a aria-current="page" href="/">होमपेज</a></li>
#  <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-1413258" id="menu-item-1413258"><a href="https://www.onlinekhabar.com/content/news/rastiya">समाचार</a></li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-735066" id="menu-item-735066"><a href="https://www.onlinekhabar.com/business">बिजनेस</a></li>
#  <li class="lifestyle-megamenu-append-wrap menu-item menu-item-type-post_type menu-item-object-page menu-item-735161" id="menu-item-735161"><a href="https://www.onlinekhabar.com/lifestyle">जीवनशैली</a></li>
#  <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-735065" id="menu-item-735065"><a href="https://www.onlinekhabar.com/entertainment">मनोरञ्जन</a></li>
# ...

# %%
for i in cat1:
    print(i.text)
# Out:
# होमपेज
# समाचार
# बिजनेस
# जीवनशैली
# मनोरञ्जन
# विचार
# खेलकुद
# अन्य

# %%
categories=[]

# %%
for i in cat1:
    categories.extend(i.text.split())

# %%
categories[:-1]
# Out:
# ['होमपेज', 'समाचार', 'बिजनेस', 'जीवनशैली', 'मनोरञ्जन', 'विचार', 'खेलकुद']

# %% [markdown]
# Homepage

# %%
url1=requests.get('https://www.onlinekhabar.com/2026/03/1889599/tensions-in-the-middle-east-oil-prices-soar-surpassing-100-per-barrel')
url1
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(url1.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="108349739223556" property="fb:pages">
# <meta content="366639890155270" property="fb:app_id">
# <title>मध्यपूर्वमा तनाव : तेलको मूल्य आकासियो, प्रतिब्यारेल १०० डलर नाघ्यो – Online Khabar</title>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://www.onlinekhabar.com/feed" rel="alternate" title="Online Khabar » Feed" type="application/rss+xml">
# <link href="https://www.onlinekhabar.com/comments/feed" rel="alternate" title="Online Khabar » Comments Feed" type="application/rss+xml"/>
# ...

# %%
h1=soup.find('div',class_="ok-post-title-right")
h1
# Out:
# <div class="ok-post-title-right">
# <h1 class="entry-title">मध्यपूर्वमा तनाव : तेलको मूल्य आकासियो, प्रतिब्यारेल १०० डलर नाघ्यो</h1> <h2 class="sgsubtitle"></h2> <div class="sgexcerpt"><p>ऊर्जा संकट ध्यानमा राख्दै केही देशले सरकारी कामकाजको समय घटाउने र घरबाट काम गर्नेजस्ता उपाय अपनाउन थालेका छन् ।</p>
# </div>
# <div class="left-fixed-items on-mobile">
# <div class="ok-post-title-left">
# <div class="ok-comment-number">
# <img alt="" src="https://www.onlinekhabar.com/wp-content/themes/onlinekhabar-2021/img/comment-blue.png">
# <a class="comment-number" href="#">
#                                         0<span>Comments</span>
# </a>
# </img></div>
# <div class="ok-post-social-shares">
# <div class="ok-share-stat">
# <span class="ok-share-num"></span>
# <span class="ok-share-label">Shares</span>
# </div>
# <div class="sharethis-inline-share-buttons"></div>
# </div>
# </div>
# </div>
# <div class="ok__container" style="margin-top:20px">
# <div class="add__fullwidth">
# ...

# %%
h1=h1.find('h1',class_="entry-title")
h1=h1.text.strip()
h1
# Out:
# 'मध्यपूर्वमा तनाव : तेलको मूल्य आकासियो, प्रतिब्यारेल १०० डलर नाघ्यो'

# %%
description = soup.find('div', class_='ok18-single-post-content-wrap')
description
# Out:
# <div class="ok18-single-post-content-wrap">
# <!-- ai summary block-->
# <div class="ai_summary_block">
# <div class="ai_summary_block_title">
# <svg fill="none" height="35" viewbox="0 0 38 35" width="38" xmlns="http://www.w3.org/2000/svg">
# <path d="M17.5 24C17.5 24 17.8035 26.8325 18.9855 28.0145C20.1675 29.1965 23 29.5 23 29.5C23 29.5 20.1675 29.8035 18.9855 30.9855C17.8035 32.1675 17.5 35 17.5 35C17.5 35 17.1965 32.1675 16.0145 30.9855C14.8325 29.8035 12 29.5 12 29.5C12 29.5 14.8325 29.1965 16.0145 28.0145C17.1965 26.8325 17.5 24 17.5 24Z" fill="black" fill-opacity="0.2"></path>
# <path d="M27.5 0C27.5 0 28.0793 5.40743 30.336 7.66405C32.5926 9.92066 38 10.5 38 10.5C38 10.5 32.5926 11.0793 30.336 13.336C28.0793 15.5926 27.5 21 27.5 21C27.5 21 26.9207 15.5926 24.664 13.336C22.4074 11.0793 17 10.5 17 10.5C17 10.5 22.4074 9.92066 24.664 7.66405C26.9207 5.40743 27.5 0 27.5 0Z" fill="#2564E5"></path>
# ...

# %%
desc1 = description.find_all('p', class_='rich-para')
desc1
# Out:
# [<p class="rich-para">२८ फागुन, काठमाडौं । मध्यपूर्व (खाडी क्षेत्र) मा थप तीन मालवाहक पानीजहाजमाथि आक्रमण भएपछि बिहीबार विश्वव्यापी तेलको मूल्यमा व्यापक वृद्धि भएको छ ।</p>,
#  <p class="rich-para">एसियाली बजारमा ब्रेन्ट कच्चा तेलको मूल्य प्रतिब्यारेल १ सय अमेरिकी डलर नाघेको छ, जसले विश्व अर्थतन्त्रमा नयाँ चुनौती थपेको छ ।</p>,
#  <p class="rich-para">यो मूल्यवृद्धि अमेरिका–इजरायल र इरानबीच जारी तनावको प्रत्यक्ष परिणाम हो । ऊर्जा ढुवानीका लागि विश्वकै सबैभन्दा महत्त्वपूर्ण जलमार्ग ‘हर्मुज स्ट्रेट’ आक्रमणको डरले लगभग बन्द छ ।</p>,
#  <p class="rich-para">इरानको रिभोलुसनरी गार्ड्स (आईआरजीसी) ले अमेरिका र उसका सहयोगीहरूसँग सम्बन्धित कुनै पनि जहाजलाई निशाना बनाउने चेतावनी दिँदै तेलको मूल्य प्रतिब्यारेल २ सय डलरसम्म पुग्न सक्ने चेतावनी दिएको छ ।</p>,
#  <p class="rich-para">बढ्दो मूल्य नियन्त्रण गर्न अन्तर्राष्ट्रिय ऊर्जा एजेन्सी (आईईए) ले आफ्नो आपतकालीन भण्डारबाट ४० करोड ब्यारेल तेल बजार पठाउने घोषणा गरे पनि बजारमा देखिएको त्रास कम हुन सकेको छैन ।</p>,
# ...

# %%
desc1 = [i.text.strip() for i in desc1]
desc1
# Out:
# ['२८ फागुन, काठमाडौं । मध्यपूर्व (खाडी क्षेत्र) मा थप तीन मालवाहक पानीजहाजमाथि आक्रमण भएपछि बिहीबार विश्वव्यापी तेलको मूल्यमा व्यापक वृद्धि भएको छ ।',
#  'एसियाली बजारमा ब्रेन्ट कच्चा तेलको मूल्य प्रतिब्यारेल १ सय अमेरिकी डलर नाघेको छ, जसले विश्व अर्थतन्त्रमा नयाँ चुनौती थपेको छ ।',
#  'यो मूल्यवृद्धि अमेरिका–इजरायल र इरानबीच जारी तनावको प्रत्यक्ष परिणाम हो । ऊर्जा ढुवानीका लागि विश्वकै सबैभन्दा महत्त्वपूर्ण जलमार्ग ‘हर्मुज स्ट्रेट’ आक्रमणको डरले लगभग बन्द छ ।',
#  'इरानको रिभोलुसनरी गार्ड्स (आईआरजीसी) ले अमेरिका र उसका सहयोगीहरूसँग सम्बन्धित कुनै पनि जहाजलाई निशाना बनाउने चेतावनी दिँदै तेलको मूल्य प्रतिब्यारेल २ सय डलरसम्म पुग्न सक्ने चेतावनी दिएको छ ।',
#  'बढ्दो मूल्य नियन्त्रण गर्न अन्तर्राष्ट्रिय ऊर्जा एजेन्सी (आईईए) ले आफ्नो आपतकालीन भण्डारबाट ४० करोड ब्यारेल तेल बजार पठाउने घोषणा गरे पनि बजारमा देखिएको त्रास कम हुन सकेको छैन ।',
#  'विज्ञहरूले यसलाई केवल ‘अस्थायी राहत’ भनेका छन् र जबसम्म आपूर्तिमाथिको खतरा रहन्छ, मूल्य उच्च नै रहने बताएका छन् ।',
# ...

# %%
desc1=' '.join(desc1)
desc1
# Out:
# '२८ फागुन, काठमाडौं । मध्यपूर्व (खाडी क्षेत्र) मा थप तीन मालवाहक पानीजहाजमाथि आक्रमण भएपछि बिहीबार विश्वव्यापी तेलको मूल्यमा व्यापक वृद्धि भएको छ । एसियाली बजारमा ब्रेन्ट कच्चा तेलको मूल्य प्रतिब्यारेल १ सय अमेरिकी डलर नाघेको छ, जसले विश्व अर्थतन्त्रमा नयाँ चुनौती थपेको छ । यो मूल्यवृद्धि अमेरिका–इजरायल र इरानबीच जारी तनावको प्रत्यक्ष परिणाम हो । ऊर्जा ढुवानीका लागि विश्वकै सबैभन्दा महत्त्वपूर्ण जलमार्ग ‘हर्मुज स्ट्रेट’ आक्रमणको डरले लगभग बन्द छ । इरानको रिभोलुसनरी गार्ड्स (आईआरजीसी) ले अमेरिका र उसका सहयोगीहरूसँग सम्बन्धित कुनै पनि जहाजलाई निशाना बनाउने चेतावनी दिँदै तेलको मूल्य प्रतिब्यारेल २ सय डलरसम्म पुग्न सक्ने चेतावनी दिएको छ । बढ्दो मूल्य नियन्त्रण गर्न अन्तर्राष्ट्रिय ऊर्जा एजेन्सी (आईईए) ले आफ्नो आपतकालीन भण्डारबाट ४० करोड ब्यारेल तेल बजार पठाउने घोषणा गरे पनि बजारमा देखिएको त्रास कम हुन सकेको छैन । विज्ञहरूले यसलाई केवल ‘अस्थायी राहत’ भनेका छन् र जबसम्म आपूर्तिमाथिको खतरा रहन्छ, मूल्य उच्च नै रहने बताएका छन् । तेलको मूल्यवृद्धिको असर विश्वभरि देखिन थालेको छ । अमेरिकामा पेट
# ...

# %%
img1 = soup.find("div", class_="post-thumbnail").find("img")
img1
# Out:
# <img src="https://www.onlinekhabar.com/wp-content/uploads/2022/01/crude-oil-price-high.jpg">
# </img>

# %%
img1=img1['src']
img1
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2022/01/crude-oil-price-high.jpg'

# %% [markdown]
# Samachar

# %%
samachar = "https://www.onlinekhabar.com/2026/03/1890051/oli-pays-tribute-to-his-father-at-the-hospital-photos"

response = requests.get(samachar)
soup = BeautifulSoup(response.content,'html.parser')

# The first main headline is inside an <h4> tag in the national news section
headline = soup.select_one(".ok-post-title-right h1")
h2=headline.text.strip()

# %%
h2
# Out:
# 'अस्पतालमा ओली पिताप्रति श्रद्धाञ्जली (तस्वीरहरु)'

# %%
description = soup.find('div', class_='ok18-single-post-content-wrap')

# %%
desc=description.find_all("p",class_="rich-para")
desc
# Out:
# [<p class="rich-para">काठमाडौं । पूर्वप्रधानमन्त्री एवं नेकपा एमालेका अध्यक्ष केपी शर्मा ओलीका बुवा मोहनप्रसादप्रति श्रद्धाञ्जली अर्पण गर्नेहरुको भिड लागेको छ । अध्यक्ष ओलीले पनि बुवाप्रति श्रद्धाञ्जली अर्पण गरेका छन् ।</p>,
#  <p class="rich-para">भक्तपुरको गठ्ठाघरस्थित नेपाल–कोरिया मैत्री अस्पतालमा मोहनप्रसादको पार्थिव शरीर राखिएको छ । त्यहाँ पुगेर श्रद्धाञ्जली अर्पण गर्ने आफन्त, नातेदार र पार्टी नेता–कार्यकर्ताहरुको भिड छ ।</p>,
#  <p class="rich-para">अध्यक्ष ओलीका बुवा मोहन प्रसाद ओलीको ९७ वर्षको उमेरमा आज बिहान नेपाल–कोरिया मैत्री अस्पतालमा निधन भएको थियो ।</p>,
#  <p class="rich-para">मोहनप्रसाद गठ्ठाघरस्थित छोरीको निवासमा बस्दै आएका थिए । गएराति अप्ठ्यारो महसुस भएपछि उनलाई अस्पताल पुर्‍याइएको थियो । अस्पतालमा उपचारको क्रममा उनको निधन भएको एमाले अध्यक्ष ओलीको सचिवालयले जनाएको छ ।</p>,
# ...

# %%
for i in desc:
    print(i.text)
# Out:
# काठमाडौं । पूर्वप्रधानमन्त्री एवं नेकपा एमालेका अध्यक्ष केपी शर्मा ओलीका बुवा मोहनप्रसादप्रति श्रद्धाञ्जली अर्पण गर्नेहरुको भिड लागेको छ । अध्यक्ष ओलीले पनि बुवाप्रति श्रद्धाञ्जली अर्पण गरेका छन् ।
# भक्तपुरको गठ्ठाघरस्थित नेपाल–कोरिया मैत्री अस्पतालमा मोहनप्रसादको पार्थिव शरीर राखिएको छ । त्यहाँ पुगेर श्रद्धाञ्जली अर्पण गर्ने आफन्त, नातेदार र पार्टी नेता–कार्यकर्ताहरुको भिड छ ।
# अध्यक्ष ओलीका बुवा मोहन प्रसाद ओलीको ९७ वर्षको उमेरमा आज बिहान नेपाल–कोरिया मैत्री अस्पतालमा निधन भएको थियो ।
# मोहनप्रसाद गठ्ठाघरस्थित छोरीको निवासमा बस्दै आएका थिए । गएराति अप्ठ्यारो महसुस भएपछि उनलाई अस्पताल पुर्‍याइएको थियो । अस्पतालमा उपचारको क्रममा उनको निधन भएको एमाले अध्यक्ष ओलीको सचिवालयले जनाएको छ ।
# गत भदौ २३ र २४ को जेनजी आन्दोलनको क्रममा मोहन प्रसादको झापास्थित घरमा पनि आगजनी भएको थियो । त्यसयता उनी झापा गएका थिएनन् । त्यसअघिसम्म उनी झापास्थित घरमा आउजाउ गरिरहन्थे ।

# %%
desc2=[]
for i in desc:
    desc2.append(i.text.replace('\u200d','').strip())

desc2
# Out:
# ['काठमाडौं । पूर्वप्रधानमन्त्री एवं नेकपा एमालेका अध्यक्ष केपी शर्मा ओलीका बुवा मोहनप्रसादप्रति श्रद्धाञ्जली अर्पण गर्नेहरुको भिड लागेको छ । अध्यक्ष ओलीले पनि बुवाप्रति श्रद्धाञ्जली अर्पण गरेका छन् ।',
#  'भक्तपुरको गठ्ठाघरस्थित नेपाल–कोरिया मैत्री अस्पतालमा मोहनप्रसादको पार्थिव शरीर राखिएको छ । त्यहाँ पुगेर श्रद्धाञ्जली अर्पण गर्ने आफन्त, नातेदार र पार्टी नेता–कार्यकर्ताहरुको भिड छ ।',
#  'अध्यक्ष ओलीका बुवा मोहन प्रसाद ओलीको ९७ वर्षको उमेरमा आज बिहान नेपाल–कोरिया मैत्री अस्पतालमा निधन भएको थियो ।',
#  'मोहनप्रसाद गठ्ठाघरस्थित छोरीको निवासमा बस्दै आएका थिए । गएराति अप्ठ्यारो महसुस भएपछि उनलाई अस्पताल पुर्याइएको थियो । अस्पतालमा उपचारको क्रममा उनको निधन भएको एमाले अध्यक्ष ओलीको सचिवालयले जनाएको छ ।',
#  'गत भदौ २३ र २४ को जेनजी आन्दोलनको क्रममा मोहन प्रसादको झापास्थित घरमा पनि आगजनी भएको थियो । त्यसयता उनी झापा गएका थिएनन् । त्यसअघिसम्म उनी झापास्थित घरमा आउजाउ गरिरहन्थे ।']

# %%
desc2=' '.join(desc2)
desc2
# Out:
# 'काठमाडौं । पूर्वप्रधानमन्त्री एवं नेकपा एमालेका अध्यक्ष केपी शर्मा ओलीका बुवा मोहनप्रसादप्रति श्रद्धाञ्जली अर्पण गर्नेहरुको भिड लागेको छ । अध्यक्ष ओलीले पनि बुवाप्रति श्रद्धाञ्जली अर्पण गरेका छन् । भक्तपुरको गठ्ठाघरस्थित नेपाल–कोरिया मैत्री अस्पतालमा मोहनप्रसादको पार्थिव शरीर राखिएको छ । त्यहाँ पुगेर श्रद्धाञ्जली अर्पण गर्ने आफन्त, नातेदार र पार्टी नेता–कार्यकर्ताहरुको भिड छ । अध्यक्ष ओलीका बुवा मोहन प्रसाद ओलीको ९७ वर्षको उमेरमा आज बिहान नेपाल–कोरिया मैत्री अस्पतालमा निधन भएको थियो । मोहनप्रसाद गठ्ठाघरस्थित छोरीको निवासमा बस्दै आएका थिए । गएराति अप्ठ्यारो महसुस भएपछि उनलाई अस्पताल पुर्याइएको थियो । अस्पतालमा उपचारको क्रममा उनको निधन भएको एमाले अध्यक्ष ओलीको सचिवालयले जनाएको छ । गत भदौ २३ र २४ को जेनजी आन्दोलनको क्रममा मोहन प्रसादको झापास्थित घरमा पनि आगजनी भएको थियो । त्यसयता उनी झापा गएका थिएनन् । त्यसअघिसम्म उनी झापास्थित घरमा आउजाउ गरिरहन्थे ।'

# %%
img2=soup.find('img',class_="aligncenter size-full wp-image-1890058")
img2=img2['src']
img2
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2026/03/Mohan-Prasad-Oli-and-KP-Sharma-Oli-3.jpg'

# %% [markdown]
# Business

# %%
business="https://www.onlinekhabar.com/2026/03/1890097/qatar-airways-announces-more-than-140-flights-in-five-days"
response=requests.get(business)
response.encoding = 'utf-8'
soup=BeautifulSoup(response.text,'html.parser')
response
# Out:
# <Response [200]>

# %%
headline=soup.find('h1',class_="entry-title")
headline
# Out:
# <h1 class="entry-title">कतार एयरवेजद्वारा पाँच दिनमा १४० भन्दा बढी उडानको घोषणा</h1>

# %%
h3=headline.text
h3
# Out:
# 'कतार एयरवेजद्वारा पाँच दिनमा १४० भन्दा बढी उडानको घोषणा'

# %%
content=soup.find('div',class_='ok18-single-post-content-wrap')
paragraph=content.find_all('p')
paragraph
# Out:
# [<p style="font-weight: 400;">२९ फागुन, काठमाडौं । कतार एयरवेजले मार्च १३ देखि मार्च १७ को बीचमा सञ्चालन गर्ने गरी कम्तीमा १४३ उडानहरूको घोषणा गरेको छ।</p>,
#  <p style="font-weight: 400;">युद्धका बीच कतारको हवाई क्षेत्र आधिकारिक रूपमा बन्द छ, तर यस राष्ट्रिय ध्वजावाहक विमान सेवाले गत साताको अन्त्यदेखि दोहामा फसेकाहरूलाई घर फर्कन र देश बाहिर फसेका कतारका बासिन्दाहरूलाई कतार फिर्ता ल्याउन मद्दत गर्ने उद्देश्यले विशेष उडानहरू सञ्चालन गरिरहेको छ।</p>,
#  <p style="font-weight: 400;">अलजजिराका अनुसार, शुक्रबार बिहानै कतार एयरवेजले मार्च १७ सम्मको आफ्नो उडान तालिका सार्वजनिक गरेको हो । यी उडानहरूमा काठमाडौंबाट प्रस्थान गर्ने र काठमाडौं आइपुग्ने कुनै उडानहरू समावेश छैनन् ।</p>,
#  <p style="font-weight: 400;"><strong>मार्च १३:</strong></p>,
#  <p style="font-weight: 400;"><strong>मार्च १४:</strong></p>,
#  <p style="font-weight: 400;"><strong>मार्च १५:</strong></p>,
#  <p style="font-weight: 400;"><strong>मार्च १६:</strong></p>,
# ...

# %%
for i in paragraph: # to get only text
    print(i.text)
# Out:
# २९ फागुन, काठमाडौं । कतार एयरवेजले मार्च १३ देखि मार्च १७ को बीचमा सञ्चालन गर्ने गरी कम्तीमा १४३ उडानहरूको घोषणा गरेको छ।
# युद्धका बीच कतारको हवाई क्षेत्र आधिकारिक रूपमा बन्द छ, तर यस राष्ट्रिय ध्वजावाहक विमान सेवाले गत साताको अन्त्यदेखि दोहामा फसेकाहरूलाई घर फर्कन र देश बाहिर फसेका कतारका बासिन्दाहरूलाई कतार फिर्ता ल्याउन मद्दत गर्ने उद्देश्यले विशेष उडानहरू सञ्चालन गरिरहेको छ।
# अलजजिराका अनुसार, शुक्रबार बिहानै कतार एयरवेजले मार्च १७ सम्मको आफ्नो उडान तालिका सार्वजनिक गरेको हो । यी उडानहरूमा काठमाडौंबाट प्रस्थान गर्ने र काठमाडौं आइपुग्ने कुनै उडानहरू समावेश छैनन् ।
# मार्च १३:
# मार्च १४:
# मार्च १५:
# मार्च १६:
# मार्च १७:

# %%
desc3=[]
for i in paragraph:
    desc3.append(i.text.replace('\xa0', ' ').strip())

desc3=desc3[:-5]
desc3
# Out:
# ['२९ फागुन, काठमाडौं । कतार एयरवेजले मार्च १३ देखि मार्च १७ को बीचमा सञ्चालन गर्ने गरी कम्तीमा १४३ उडानहरूको घोषणा गरेको छ।',
#  'युद्धका बीच कतारको हवाई क्षेत्र आधिकारिक रूपमा बन्द छ, तर यस राष्ट्रिय ध्वजावाहक विमान सेवाले गत साताको अन्त्यदेखि दोहामा फसेकाहरूलाई घर फर्कन र देश बाहिर फसेका कतारका बासिन्दाहरूलाई कतार फिर्ता ल्याउन मद्दत गर्ने उद्देश्यले विशेष उडानहरू सञ्चालन गरिरहेको छ।',
#  'अलजजिराका अनुसार, शुक्रबार बिहानै कतार एयरवेजले मार्च १७ सम्मको आफ्नो उडान तालिका सार्वजनिक गरेको हो । यी उडानहरूमा काठमाडौंबाट प्रस्थान गर्ने र काठमाडौं आइपुग्ने कुनै उडानहरू समावेश छैनन् ।']

# %%
desc3=" ".join(desc3)
desc3
# Out:
# '२९ फागुन, काठमाडौं । कतार एयरवेजले मार्च १३ देखि मार्च १७ को बीचमा सञ्चालन गर्ने गरी कम्तीमा १४३ उडानहरूको घोषणा गरेको छ। युद्धका बीच कतारको हवाई क्षेत्र आधिकारिक रूपमा बन्द छ, तर यस राष्ट्रिय ध्वजावाहक विमान सेवाले गत साताको अन्त्यदेखि दोहामा फसेकाहरूलाई घर फर्कन र देश बाहिर फसेका कतारका बासिन्दाहरूलाई कतार फिर्ता ल्याउन मद्दत गर्ने उद्देश्यले विशेष उडानहरू सञ्चालन गरिरहेको छ। अलजजिराका अनुसार, शुक्रबार बिहानै कतार एयरवेजले मार्च १७ सम्मको आफ्नो उडान तालिका सार्वजनिक गरेको हो । यी उडानहरूमा काठमाडौंबाट प्रस्थान गर्ने र काठमाडौं आइपुग्ने कुनै उडानहरू समावेश छैनन् ।'

# %%
img3=soup.find("div",class_="post-thumbnail").find('img')['src']
img3
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2026/03/Qatar_Airways_Airbus_A350-1000_A7-ANA-1024x683.jpg'

# %% [markdown]
# Lifestyle

# %%
url="https://www.onlinekhabar.com/2026/03/1889804/preparations-for-kathmandu-pink-carethon-2026-complete"
response=requests.get(url)
response.encoding = 'utf-8'
soup=BeautifulSoup(response.text, 'html.parser')

# %%
h4=soup.find("h1",class_="entry-title")
h4=h4.text
h4
# Out:
# '‘काठमाडौं पिंककेयरथन २०२६’ को तयारी पूरा'

# %%
content= soup.find('div',class_="ok18-single-post-content-wrap").find_all('p')
content
# Out:
# [<p>२८ फागुन, काठमाडौं । लेजरपोर्ट नेपालको आयोजनामा काठमाडौं पिंककेयरथन यही फागुन ३० गते जावलाखेल फुटबल ग्राउण्डमा आयोजना हुने भएको छ । कार्यक्रमको सम्पूर्ण तयारी पूरा भएको आयोजकले जानकारी दिएका छन् ।</p>,
#  <p>आयोजकका अनुसार महिलाहरूलाई स्वास्थ्य र जीवनशैलीप्रति सचेत बनाउन तथा फिटनेसप्रति प्रेरित गर्ने उद्देश्यले कार्यक्रम आयोजना गर्न लागिएको हो ।</p>,
#  <p>बिहान ६ बजेदेखि जुम्बा सत्रबाट कार्यक्रम सुरु हुनेछ । त्यसपछि म्याराथन प्रतियोगिता सञ्चालन गरिनेछ । आयोजक लेजरपोर्ट नेपालका अध्यक्ष नमराज जोशिका अनुसार प्रतियोगितामा २१.१ किलोमिटर हाफ म्याराथन, १० किलोमिटर दौड साथै ५ किलोमिटर र ३ किलोमिटर फन रन समावेश गरिएको छ ।</p>,
#  <p>यस वर्ष ओलम्पियन धाविका सन्तोषी श्रेष्ठ २१ किलोमिटर हाफ म्याराथनमा सहभागी हुनेभएकी छिन् । साथै अन्य व्यावसायिक धावकहरू पनि प्रतियोगितामा सहभागी हुने आयोजकले जानकारी दिएका छन् ।</p>,
# ...

# %%
desc4=[]
for i in content:
    desc4.append(i.text)
desc4
# Out:
# ['२८ फागुन, काठमाडौं । लेजरपोर्ट नेपालको आयोजनामा काठमाडौं पिंककेयरथन यही फागुन ३० गते जावलाखेल फुटबल ग्राउण्डमा आयोजना हुने भएको छ । कार्यक्रमको सम्पूर्ण तयारी पूरा भएको आयोजकले जानकारी दिएका छन् ।',
#  'आयोजकका अनुसार महिलाहरूलाई स्वास्थ्य र जीवनशैलीप्रति सचेत बनाउन तथा फिटनेसप्रति प्रेरित गर्ने उद्देश्यले कार्यक्रम आयोजना गर्न लागिएको हो ।',
#  'बिहान ६ बजेदेखि जुम्बा सत्रबाट कार्यक्रम सुरु हुनेछ । त्यसपछि म्याराथन प्रतियोगिता सञ्चालन गरिनेछ । आयोजक लेजरपोर्ट नेपालका अध्यक्ष नमराज जोशिका अनुसार प्रतियोगितामा २१.१ किलोमिटर हाफ म्याराथन, १० किलोमिटर दौड साथै ५ किलोमिटर र ३ किलोमिटर फन रन समावेश गरिएको छ ।',
#  'यस वर्ष ओलम्पियन धाविका सन्तोषी श्रेष्ठ २१ किलोमिटर हाफ म्याराथनमा सहभागी हुनेभएकी छिन् । साथै अन्य व्यावसायिक धावकहरू पनि प्रतियोगितामा सहभागी हुने आयोजकले जानकारी दिएका छन् ।',
#  'हाफ म्याराथनतर्फका विजेताहरूलाई क्रमशः ५१ हजार, ३१ हजार र २१ हजार रुपैयाँ पुरस्कार प्रदान गरिनेछ भने १० किलोमिटर दौडका विजेताहरूलाई ३१ हजार, २१ हजार र ११ हजार रुपैयाँ पुरस्कार प्रदान गरिनेछ ।',
# ...

# %%
desc4=' '.join(desc4)
desc4
# Out:
# '२८ फागुन, काठमाडौं । लेजरपोर्ट नेपालको आयोजनामा काठमाडौं पिंककेयरथन यही फागुन ३० गते जावलाखेल फुटबल ग्राउण्डमा आयोजना हुने भएको छ । कार्यक्रमको सम्पूर्ण तयारी पूरा भएको आयोजकले जानकारी दिएका छन् । आयोजकका अनुसार महिलाहरूलाई स्वास्थ्य र जीवनशैलीप्रति सचेत बनाउन तथा फिटनेसप्रति प्रेरित गर्ने उद्देश्यले कार्यक्रम आयोजना गर्न लागिएको हो । बिहान ६ बजेदेखि जुम्बा सत्रबाट कार्यक्रम सुरु हुनेछ । त्यसपछि म्याराथन प्रतियोगिता सञ्चालन गरिनेछ । आयोजक लेजरपोर्ट नेपालका अध्यक्ष नमराज जोशिका अनुसार प्रतियोगितामा २१.१ किलोमिटर हाफ म्याराथन, १० किलोमिटर दौड साथै ५ किलोमिटर र ३ किलोमिटर फन रन समावेश गरिएको छ । यस वर्ष ओलम्पियन धाविका सन्तोषी श्रेष्ठ २१ किलोमिटर हाफ म्याराथनमा सहभागी हुनेभएकी छिन् । साथै अन्य व्यावसायिक धावकहरू पनि प्रतियोगितामा सहभागी हुने आयोजकले जानकारी दिएका छन् । हाफ म्याराथनतर्फका विजेताहरूलाई क्रमशः ५१ हजार, ३१ हजार र २१ हजार रुपैयाँ पुरस्कार प्रदान गरिनेछ भने १० किलोमिटर दौडका विजेताहरूलाई ३१ हजार, २१ हजार र ११ हजार रुपैयाँ पुरस्कार प्रदान गरिनेछ । अन्य विभिन्न विधामा पनि नगदस
# ...

# %%
img4=soup.find("div",class_="post-thumbnail").find('img')['src']
img4
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2026/03/pinkcareathan-1024x557.jpg'

# %% [markdown]
# Entertainment

# %%
url="https://www.onlinekhabar.com/2026/03/1890187/netflix-announces-second-season-of-k-pop-demon-hunters"
response=requests.get(url)
response.encoding = 'utf-8'
soup=BeautifulSoup(response.text,'html.parser')

# %%
headline=soup.find("h1",class_="entry-title")
h5=headline.text.strip()
h5
# Out:
# '‘के-पप डेमन हन्टर्स’ को दोस्रो श्रृंखला ल्याउने नेटफ्ल्क्सिको घोषणा'

# %%
news=soup.find("div",class_="ok18-single-post-content-wrap").find_all('p')
news
# Out:
# [<p style="text-align: justify;">बीबीसी । नेटफ्लिक्सले प्लेटफर्ममा अहिलेसम्म सबैभन्दा धेरै हेरिएको फिल्म ‘के-पप डेमन हन्टर्स’ को सिक्वेल बनाउने घोषणा गरेको छ ।</p>,
#  <p style="text-align: justify;">यस सिक्वेल कहिले रिलिज हुनेछ भन्ने मिति भने अझै तय गरिएको छैन । सह-निर्देशक म्यागी काङ र क्रिस एपेलहन्सले नेटफ्लिक्ससँग गरेको नयाँ बहुवर्षीय विशेष सम्झौताअन्तर्गत बन्ने यो पहिलो प्रोजेक्ट हुनेछ ।</p>,
#  <p style="text-align: justify;">यसैबीच, समीक्षकले यस फिल्मले नेपाली समयानुसार सोमबार हुने अस्क अवार्डमा सफलता हात पार्ने अनुमान गरेका छन् । उक्त फिल्म उत्कृष्ट एनिमेटेड फिल्म र उत्कृष्ट मौलिक गीत गरी दुई विधामा मनोनयनमा परेको छ ।</p>,
#  <p style="text-align: justify;">फिल्मको गीत ‘गोल्डेन’ले ग्रामी अवार्डमा ‘दृश्य माध्यमका लागि लेखिएको उत्कृष्ट गीत’ विधामा पुरस्कार जितिसकेको छ । प्रतिष्ठित ग्रामी अवार्डमा कुनै के-पप गीतले पहिलोपटक यस्तो सम्मान पाएको हो ।</p>,
# ...

# %%
desc5=[]
for i in news:
    desc5.append(i.text)

desc5
# Out:
# ['बीबीसी । नेटफ्लिक्सले प्लेटफर्ममा अहिलेसम्म सबैभन्दा धेरै हेरिएको फिल्म ‘के-पप डेमन हन्टर्स’ को सिक्वेल बनाउने घोषणा गरेको छ ।',
#  'यस सिक्वेल कहिले रिलिज हुनेछ भन्ने मिति भने अझै तय गरिएको छैन । सह-निर्देशक म्यागी काङ र क्रिस एपेलहन्सले नेटफ्लिक्ससँग गरेको नयाँ बहुवर्षीय विशेष सम्झौताअन्तर्गत बन्ने यो पहिलो प्रोजेक्ट हुनेछ ।',
#  'यसैबीच, समीक्षकले यस फिल्मले नेपाली समयानुसार सोमबार हुने अस्क अवार्डमा सफलता हात पार्ने अनुमान गरेका छन् । उक्त फिल्म उत्कृष्ट एनिमेटेड फिल्म र उत्कृष्ट मौलिक गीत गरी दुई विधामा मनोनयनमा परेको छ ।',
#  'फिल्मको गीत ‘गोल्डेन’ले ग्रामी अवार्डमा ‘दृश्य माध्यमका लागि लेखिएको उत्कृष्ट गीत’ विधामा पुरस्कार जितिसकेको छ । प्रतिष्ठित ग्रामी अवार्डमा कुनै के-पप गीतले पहिलोपटक यस्तो सम्मान पाएको हो ।',
#  'मूल फिल्मको कथा के-पप समूह ‘हुन्ट्र/एक्स’का मुख्य पात्र रुमी, मिरा र जोई वरिपरि घुम्छ । उनीहरू एकातिर प्रसिद्धि र चर्चासँग जुधिरहेका हुन्छन् भने अर्कोतिर गुप्त रूपमा राक्षस सिकार गर्ने आफ्नो जीवन पनि सम्हालिरहेका हुन्छन् ।',
# ...

# %%
desc5='\n'.join(desc5)
print(desc5)
# Out:
# बीबीसी । नेटफ्लिक्सले प्लेटफर्ममा अहिलेसम्म सबैभन्दा धेरै हेरिएको फिल्म ‘के-पप डेमन हन्टर्स’ को सिक्वेल बनाउने घोषणा गरेको छ ।
# यस सिक्वेल कहिले रिलिज हुनेछ भन्ने मिति भने अझै तय गरिएको छैन । सह-निर्देशक म्यागी काङ र क्रिस एपेलहन्सले नेटफ्लिक्ससँग गरेको नयाँ बहुवर्षीय विशेष सम्झौताअन्तर्गत बन्ने यो पहिलो प्रोजेक्ट हुनेछ ।
# यसैबीच, समीक्षकले यस फिल्मले नेपाली समयानुसार सोमबार हुने अस्क अवार्डमा सफलता हात पार्ने अनुमान गरेका छन् । उक्त फिल्म उत्कृष्ट एनिमेटेड फिल्म र उत्कृष्ट मौलिक गीत गरी दुई विधामा मनोनयनमा परेको छ ।
# फिल्मको गीत ‘गोल्डेन’ले ग्रामी अवार्डमा ‘दृश्य माध्यमका लागि लेखिएको उत्कृष्ट गीत’ विधामा पुरस्कार जितिसकेको छ । प्रतिष्ठित ग्रामी अवार्डमा कुनै के-पप गीतले पहिलोपटक यस्तो सम्मान पाएको हो ।
# मूल फिल्मको कथा के-पप समूह ‘हुन्ट्र/एक्स’का मुख्य पात्र रुमी, मिरा र जोई वरिपरि घुम्छ । उनीहरू एकातिर प्रसिद्धि र चर्चासँग जुधिरहेका हुन्छन् भने अर्कोतिर गुप्त रूपमा राक्षस सिकार गर्ने आफ्नो जीवन पनि सम्हालिरहेका हुन्छन् ।
# ...

# %%
img5=soup.find('div',class_="post-thumbnail").find('img')['src']
img5
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2026/03/kpop_demon_hunters.jpg'

# %% [markdown]
# Opinion

# %%
bichar="https://www.onlinekhabar.com/2026/03/1889983/why-did-the-peoples-court-make-such-a-cruel-decision"
response=requests.get(bichar)
response.encoding = 'utf-8'
soup=BeautifulSoup(response.text,'html.parser')

# %%
headline = soup.find("h1",class_='entry-title')
h6=headline.text.replace('\u200d','').strip()
h6
# Out:
# 'जनताको अदालतले किन गर्यो निर्मम फैसला ?'

# %%
content=soup.find('div',class_="ok18-single-post-content-wrap").find_all("p")
content
# Out:
# [<p>लोकतान्त्रिक राजनीतिक इतिहासको एउटा रोचक सत्य के हो भने कुनै समय अत्यन्त शक्तिशाली देखिएका राजनीतिक दलहरू पनि अचानक मतदाताको कठोर निर्णयका कारण कमजोर वा लगभग समाप्त हुन सक्छन्। राजनीतिक शक्ति स्थायी हुँदैन, जनताको विश्वास नै यसको आधार हो।</p>,
#  <p>जब कुनै दलले आफ्नो सिद्धान्त, नीति र व्यवहारबीच सन्तुलन कायम गर्न सक्दैन, तब जनताले त्यसलाई अस्वीकार गर्न सक्छन्। संसारका धेरै देशहरूमा यस्ता घटनाहरू भएका छन्, जसले लोकतन्त्रको चरित्रलाई अझ स्पष्ट बनाएका छन्। क्यानडाको सन् १९९३ को चुनाव, भारतको १९७७ को चुनाव, पश्चिम बंगालको सन् २०११ को परिवर्तन र बङ्गलादेशका चुनावी उतारचढाव यसका महत्त्वपूर्ण उदाहरण हुन्। यस्ता घटनाहरूलाई हेर्दा नेपालको वर्तमान राजनीतिक परिस्थिति पनि गम्भीर रूपमा विश्लेषण गर्नुपर्ने आवश्यकता देखिन्छ।</p>,
# ...

# %%
desc6=[]
for i in content:
    desc6.append(i.text.strip())


desc6
# Out:
# ['लोकतान्त्रिक राजनीतिक इतिहासको एउटा रोचक सत्य के हो भने कुनै समय अत्यन्त शक्तिशाली देखिएका राजनीतिक दलहरू पनि अचानक मतदाताको कठोर निर्णयका कारण कमजोर वा लगभग समाप्त हुन सक्छन्। राजनीतिक शक्ति स्थायी हुँदैन, जनताको विश्वास नै यसको आधार हो।',
#  'जब कुनै दलले आफ्नो सिद्धान्त, नीति र व्यवहारबीच सन्तुलन कायम गर्न सक्दैन, तब जनताले त्यसलाई अस्वीकार गर्न सक्छन्। संसारका धेरै देशहरूमा यस्ता घटनाहरू भएका छन्, जसले लोकतन्त्रको चरित्रलाई अझ स्पष्ट बनाएका छन्। क्यानडाको सन् १९९३ को चुनाव, भारतको १९७७ को चुनाव, पश्चिम बंगालको सन् २०११ को परिवर्तन र बङ्गलादेशका चुनावी उतारचढाव यसका महत्त्वपूर्ण उदाहरण हुन्। यस्ता घटनाहरूलाई हेर्दा नेपालको वर्तमान राजनीतिक परिस्थिति पनि गम्भीर रूपमा विश्लेषण गर्नुपर्ने आवश्यकता देखिन्छ।',
# ...

# %%
desc6=' '.join(desc6)
desc6
# Out:
# 'लोकतान्त्रिक राजनीतिक इतिहासको एउटा रोचक सत्य के हो भने कुनै समय अत्यन्त शक्तिशाली देखिएका राजनीतिक दलहरू पनि अचानक मतदाताको कठोर निर्णयका कारण कमजोर वा लगभग समाप्त हुन सक्छन्। राजनीतिक शक्ति स्थायी हुँदैन, जनताको विश्वास नै यसको आधार हो। जब कुनै दलले आफ्नो सिद्धान्त, नीति र व्यवहारबीच सन्तुलन कायम गर्न सक्दैन, तब जनताले त्यसलाई अस्वीकार गर्न सक्छन्। संसारका धेरै देशहरूमा यस्ता घटनाहरू भएका छन्, जसले लोकतन्त्रको चरित्रलाई अझ स्पष्ट बनाएका छन्। क्यानडाको सन् १९९३ को चुनाव, भारतको १९७७ को चुनाव, पश्चिम बंगालको सन् २०११ को परिवर्तन र बङ्गलादेशका चुनावी उतारचढाव यसका महत्त्वपूर्ण उदाहरण हुन्। यस्ता घटनाहरूलाई हेर्दा नेपालको वर्तमान राजनीतिक परिस्थिति पनि गम्भीर रूपमा विश्लेषण गर्नुपर्ने आवश्यकता देखिन्छ। संसारको चुनावी इतिहासमा सबैभन्दा ठूलो हारको उदाहरण क्यानडाको सन् १९९३ को संसदीय चुनावलाई मानिन्छ। त्यतिबेला सत्तारूढ दल द प्रोग्रेसिभ कन्जरभेटिभ पार्टी अफ क्यानडा (पीसीसी) संसद्\u200cमा अत्यन्त बलियो अवस्थामा थियो। यस दलले केही वर्षअघि मात्रै विशाल बहुमतसहित सरकार बनाएको थियो। सन् १९८४ 
# ...

# %%
img6=soup.find("div",class_='post-thumbnail').find('img')['src']
img6
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2026/03/nabinbandhu-pahadi-1024x500.jpg'

# %% [markdown]
# Khelkud

# %%
url="https://www.onlinekhabar.com/2026/03/1890208/reconstruction-of-narayani-stadium-in-birgunj-begins"
response=requests.get(url)
response.encoding='utf-8'
soup=BeautifulSoup(response.text,'html.parser')

# %%
headline = soup.find("div",class_="single-post-heading").find('h1')
h7=headline.text.strip()
h7
# Out:
# 'वीरगञ्जको नारायणी रंगशालाको पुनर्निर्माण सुरु'

# %%
content=soup.find("div",class_="ok18-single-post-content-wrap").find_all('p')
content
# Out:
# [<p class="rich-para">२९ फागुन, वीरगञ्ज । पर्साको वीरगञ्जस्थित नारायणी रंगशालाको मर्मत तथा पुनर्निर्माण कार्य औपचारिक रूपमा सुरु गरिएको छ । रंगशालाको जीर्ण संरचना हटाएर नयाँ निर्माण गर्ने प्रक्रिया आजदेखि सुरु भएको हो ।</p>,
#  <p class="rich-para">पर्सा जिल्ला खेलकुद विकास समितिका अध्यक्ष दीपककुमार कानुका अनुसार पहिलो चरणमा पुराना र जीर्ण ८८ प्याराफिटहरू डोजर प्रयोग गरेर भत्काउने काम सुरु गरिएको छ । ती संरचना हटाइसकेपछि नयाँ प्याराफिट निर्माण गरिने योजना रहेको उनले बताए ।</p>,
#  <p class="rich-para">सरकारले चालु आर्थिक वर्ष २०८२/८३ को बजेटमार्फत रंगशालाको पुनर्निर्माणका लागि ४ करोड रुपैयाँ विनियोजन गरेको थियो । उक्त बजेट निकासा भएपछि निर्माण कार्य अघि बढाइएको हो । अध्यक्ष कानुका अनुसार तत्कालीन कानुनमन्त्री अजय चौरसियाको पहलमा तत्कालीन युवा तथा खेलकुदमन्त्री तेजुलाल चौधरीले बजेटमा यो रकम व्यवस्था गरेका थिए ।</p>,
# ...

# %%
desc7 = []
for i in content:
    text = i.text.strip()
    if text:  # only append if not empty
        desc7.append(text)
desc7
# Out:
# ['२९ फागुन, वीरगञ्ज । पर्साको वीरगञ्जस्थित नारायणी रंगशालाको मर्मत तथा पुनर्निर्माण कार्य औपचारिक रूपमा सुरु गरिएको छ । रंगशालाको जीर्ण संरचना हटाएर नयाँ निर्माण गर्ने प्रक्रिया आजदेखि सुरु भएको हो ।',
#  'पर्सा जिल्ला खेलकुद विकास समितिका अध्यक्ष दीपककुमार कानुका अनुसार पहिलो चरणमा पुराना र जीर्ण ८८ प्याराफिटहरू डोजर प्रयोग गरेर भत्काउने काम सुरु गरिएको छ । ती संरचना हटाइसकेपछि नयाँ प्याराफिट निर्माण गरिने योजना रहेको उनले बताए ।',
#  'सरकारले चालु आर्थिक वर्ष २०८२/८३ को बजेटमार्फत रंगशालाको पुनर्निर्माणका लागि ४ करोड रुपैयाँ विनियोजन गरेको थियो । उक्त बजेट निकासा भएपछि निर्माण कार्य अघि बढाइएको हो । अध्यक्ष कानुका अनुसार तत्कालीन कानुनमन्त्री अजय चौरसियाको पहलमा तत्कालीन युवा तथा खेलकुदमन्त्री तेजुलाल चौधरीले बजेटमा यो रकम व्यवस्था गरेका थिए ।',
#  'हाल उपलब्ध रकमबाट प्रारम्भिक चरणका काम मात्रै सम्पन्न गरिने बताइएको छ । रंगशालाको पूर्ण मर्मत र स्तरोन्नतिका लागि भने थप बजेट आवश्यक पर्ने अध्यक्ष कानुले जानकारी दिए ।',
# ...

# %%
desc7=' '.join(desc7)
desc7
# Out:
# '२९ फागुन, वीरगञ्ज । पर्साको वीरगञ्जस्थित नारायणी रंगशालाको मर्मत तथा पुनर्निर्माण कार्य औपचारिक रूपमा सुरु गरिएको छ । रंगशालाको जीर्ण संरचना हटाएर नयाँ निर्माण गर्ने प्रक्रिया आजदेखि सुरु भएको हो । पर्सा जिल्ला खेलकुद विकास समितिका अध्यक्ष दीपककुमार कानुका अनुसार पहिलो चरणमा पुराना र जीर्ण ८८ प्याराफिटहरू डोजर प्रयोग गरेर भत्काउने काम सुरु गरिएको छ । ती संरचना हटाइसकेपछि नयाँ प्याराफिट निर्माण गरिने योजना रहेको उनले बताए । सरकारले चालु आर्थिक वर्ष २०८२/८३ को बजेटमार्फत रंगशालाको पुनर्निर्माणका लागि ४ करोड रुपैयाँ विनियोजन गरेको थियो । उक्त बजेट निकासा भएपछि निर्माण कार्य अघि बढाइएको हो । अध्यक्ष कानुका अनुसार तत्कालीन कानुनमन्त्री अजय चौरसियाको पहलमा तत्कालीन युवा तथा खेलकुदमन्त्री तेजुलाल चौधरीले बजेटमा यो रकम व्यवस्था गरेका थिए । हाल उपलब्ध रकमबाट प्रारम्भिक चरणका काम मात्रै सम्पन्न गरिने बताइएको छ । रंगशालाको पूर्ण मर्मत र स्तरोन्नतिका लागि भने थप बजेट आवश्यक पर्ने अध्यक्ष कानुले जानकारी दिए । पहिलो चरणको निर्माण पूरा भएपछि नेपाल सरकार र युवा तथा खेलकुद मन्त्रालयसँग थप बजेट माग ग
# ...

# %%
img7=soup.find("div",class_="post-thumbnail").find('img')['src']
img7
# Out:
# 'https://www.onlinekhabar.com/wp-content/uploads/2026/03/Narayani-ranghashala-scaled.png'

# %%
# Making enpty list.

Main_news=[]
Description=[]
Picture_link=[]

# %%
Main_news=[]
Main_news.extend([h1,h2,h3,h4,h5,h6,h7])
Main_news
# Out:
# ['मध्यपूर्वमा तनाव : तेलको मूल्य आकासियो, प्रतिब्यारेल १०० डलर नाघ्यो',
#  'अस्पतालमा ओली पिताप्रति श्रद्धाञ्जली (तस्वीरहरु)',
#  'कतार एयरवेजद्वारा पाँच दिनमा १४० भन्दा बढी उडानको घोषणा',
#  '‘काठमाडौं पिंककेयरथन २०२६’ को तयारी पूरा',
#  '‘के-पप डेमन हन्टर्स’ को दोस्रो श्रृंखला ल्याउने नेटफ्ल्क्सिको घोषणा',
#  'जनताको अदालतले किन गर्यो निर्मम फैसला ?',
#  'वीरगञ्जको नारायणी रंगशालाको पुनर्निर्माण सुरु']

# %%
Description.extend([desc1,desc2,desc3,desc4,desc5,desc6,desc7])
Description
# Out:
# ['२८ फागुन, काठमाडौं । मध्यपूर्व (खाडी क्षेत्र) मा थप तीन मालवाहक पानीजहाजमाथि आक्रमण भएपछि बिहीबार विश्वव्यापी तेलको मूल्यमा व्यापक वृद्धि भएको छ । एसियाली बजारमा ब्रेन्ट कच्चा तेलको मूल्य प्रतिब्यारेल १ सय अमेरिकी डलर नाघेको छ, जसले विश्व अर्थतन्त्रमा नयाँ चुनौती थपेको छ । यो मूल्यवृद्धि अमेरिका–इजरायल र इरानबीच जारी तनावको प्रत्यक्ष परिणाम हो । ऊर्जा ढुवानीका लागि विश्वकै सबैभन्दा महत्त्वपूर्ण जलमार्ग ‘हर्मुज स्ट्रेट’ आक्रमणको डरले लगभग बन्द छ । इरानको रिभोलुसनरी गार्ड्स (आईआरजीसी) ले अमेरिका र उसका सहयोगीहरूसँग सम्बन्धित कुनै पनि जहाजलाई निशाना बनाउने चेतावनी दिँदै तेलको मूल्य प्रतिब्यारेल २ सय डलरसम्म पुग्न सक्ने चेतावनी दिएको छ । बढ्दो मूल्य नियन्त्रण गर्न अन्तर्राष्ट्रिय ऊर्जा एजेन्सी (आईईए) ले आफ्नो आपतकालीन भण्डारबाट ४० करोड ब्यारेल तेल बजार पठाउने घोषणा गरे पनि बजारमा देखिएको त्रास कम हुन सकेको छैन । विज्ञहरूले यसलाई केवल ‘अस्थायी राहत’ भनेका छन् र जबसम्म आपूर्तिमाथिको खतरा रहन्छ, मूल्य उच्च नै रहने बताएका छन् । तेलको मूल्यवृद्धिको असर विश्वभरि देखिन थालेको छ । अमेरिकामा पे
# ...

# %%
Picture_link.extend([img1,img2,img3,img4,img5,img6,img7])
Picture_link
# Out:
# ['https://www.onlinekhabar.com/wp-content/uploads/2022/01/crude-oil-price-high.jpg',
#  'https://www.onlinekhabar.com/wp-content/uploads/2026/03/Mohan-Prasad-Oli-and-KP-Sharma-Oli-3.jpg',
#  'https://www.onlinekhabar.com/wp-content/uploads/2026/03/Qatar_Airways_Airbus_A350-1000_A7-ANA-1024x683.jpg',
#  'https://www.onlinekhabar.com/wp-content/uploads/2026/03/pinkcareathan-1024x557.jpg',
#  'https://www.onlinekhabar.com/wp-content/uploads/2026/03/kpop_demon_hunters.jpg',
#  'https://www.onlinekhabar.com/wp-content/uploads/2026/03/nabinbandhu-pahadi-1024x500.jpg',
#  'https://www.onlinekhabar.com/wp-content/uploads/2026/03/Narayani-ranghashala-scaled.png']

# %%
categories
# Out:
# ['होमपेज',
#  'समाचार',
#  'बिजनेस',
#  'जीवनशैली',
#  'मनोरञ्जन',
#  'विचार',
#  'खेलकुद',
#  'अन्य']

# %%
categories.pop(-1)
# Out:
# 'अन्य'

# %%
categories
# Out:
# ['होमपेज', 'समाचार', 'बिजनेस', 'जीवनशैली', 'मनोरञ्जन', 'विचार', 'खेलकुद']

# %%
import pandas as pd
data={
    "वर्गहरू": categories,
    "मुख्य समाचार": Main_news,
    "विवरण": Description,
    "तस्बिरको लिंक": Picture_link

}

# %%
pd.set_option('display.max_colwidth', None) # to display all the contents without cutting.

# %%
print(len(categories))
print(len(Main_news))
print(len(Description))
print(len(Picture_link))
# Out:
# 7
# 7
# 7
# 7

# %%
df=pd.DataFrame(data)
df
# Out:
#     वर्गहरू  \
# 0    होमपेज
# 1    समाचार
# 2    बिजनेस
# 3  जीवनशैली
# 4  मनोरञ्जन
# 5     विचार
# 6    खेलकुद
#
#                                                           मुख्य समाचार  \
# 0  मध्यपूर्वमा तनाव : तेलको मूल्य आकासियो, प्रतिब्यारेल १०० डलर नाघ्यो
# 1                     अस्पतालमा ओली पिताप्रति श्रद्धाञ्जली (तस्वीरहरु)
# 2              कतार एयरवेजद्वारा पाँच दिनमा १४० भन्दा बढी उडानको घोषणा
# 3                             ‘काठमाडौं पिंककेयरथन २०२६’ को तयारी पूरा
# 4  ‘के-पप डेमन हन्टर्स’ को दोस्रो श्रृंखला ल्याउने नेटफ्ल्क्सिको घोषणा
# 5                              जनताको अदालतले किन गर्यो निर्मम फैसला ?
# 6                        वीरगञ्जको नारायणी रंगशालाको पुनर्निर्माण सुरु
#
# ...

# %%
df.to_csv('news.csv', index=False)
